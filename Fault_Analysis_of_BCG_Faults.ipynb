# %% [markdown]
# <a href="https://colab.research.google.com/github/Abinash-bit/fault-analysis-randomforest/blob/master/Fault_Analysis_of_BCG_Faults.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("/content/BCG modified.csv")

# %%
dataset.head()
# Out:
#        Time  Absolute Ia  Absolute Ib  Absolute Ic Fault
# 0  0.000000     0.008215     0.192289     0.164458    No
# 1  0.000167     0.014444     0.194102     0.161226    No
# 2  0.000333     0.020655     0.195216     0.157385    No
# 3  0.000500     0.026836     0.195626     0.152939    No
# 4  0.000667     0.032972     0.195325     0.147891    No

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6000 entries, 0 to 5999
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Time         6000 non-null   float64
#  1   Absolute Ia  6000 non-null   float64
#  2   Absolute Ib  6000 non-null   float64
#  3   Absolute Ic  6000 non-null   float64
#  4   Fault        6000 non-null   object
# dtypes: float64(4), object(1)
# memory usage: 234.5+ KB

# %%
dataset.describe().T
# Out:
#               count      mean       std       min       25%       50%  \
# Time         6000.0  0.499897  0.288688  0.000000  0.249948  0.499897
# Absolute Ia  6000.0  0.096091  0.071256  0.000025  0.046470  0.083526
# Absolute Ib  6000.0  0.178664  0.141925  0.000029  0.089705  0.159148
# Absolute Ic  6000.0  0.180611  0.173667  0.000110  0.081324  0.141246
#
#                   75%       max
# Time         0.749845  0.999793
# Absolute Ia  0.119296  0.361360
# Absolute Ib  0.195684  0.796454
# Absolute Ic  0.192132  1.034388

# %%
g = sns.pairplot(dataset, hue='Fault')
g.fig.suptitle("Scatterplot and histogram of pairs of variables color coded by Fault risks",
               fontsize = 14,
               y=1.05);

# %%
dataset['Fault'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
dataset['Fault'] = dataset['Fault'].replace('No', 0).replace('Yes', 1)

# %%
y = dataset['Fault']
X = dataset.drop(['Fault'], axis=1)

# %%
from sklearn.model_selection import train_test_split

SEED = 42
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.2,
                                                    random_state=SEED)

# %%
from sklearn.ensemble import RandomForestClassifier

rfc = RandomForestClassifier(n_estimators=3,
                             max_depth=2,
                             random_state=SEED)

# %%
# Fit RandomForestClassifier
rfc.fit(X_train, y_train)
# Predict the test set labels
y_pred = rfc.predict(X_test)

# %%
# Import `tree` module
from sklearn import tree

features = X.columns.values
classes = ['0', '1']

for estimator in rfc.estimators_:
    print(estimator)
    plt.figure(figsize=(12,6))
    tree.plot_tree(estimator,
                   feature_names=features,
                   class_names=classes,
                   fontsize=8,
                   filled=True,
                   rounded=True)
    plt.show()
# Out:
# DecisionTreeClassifier(max_depth=2, max_features='sqrt',
#                        random_state=1608637542)
# DecisionTreeClassifier(max_depth=2, max_features='sqrt',
#                        random_state=1273642419)
# DecisionTreeClassifier(max_depth=2, max_features='sqrt',
#                        random_state=1935803228)

# %%
from sklearn.metrics import classification_report, confusion_matrix

cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d').set_title('Fault risks confusion matrix (0 = No, 1 = Yes)')

print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98       955
#            1       1.00      0.82      0.90       245
#
#     accuracy                           0.96      1200
#    macro avg       0.98      0.91      0.94      1200
# weighted avg       0.97      0.96      0.96      1200

# %%
features_df = pd.DataFrame({'features': rfc.feature_names_in_, 'importances': rfc.feature_importances_ })


features_df_sorted = features_df.sort_values(by='importances', ascending=False)


g = sns.barplot(data=features_df_sorted, x='importances', y ='features', palette="rocket")
sns.despine(bottom = True, left = True)
g.set_title('Feature importances')
g.set(xlabel=None)
g.set(ylabel=None)
g.set(xticks=[])
for value in g.containers:
    g.bar_label(value, padding=2)

# %%
rfc_ = RandomForestClassifier(n_estimators=900,
                             max_depth=7,
                             random_state=SEED)
rfc_.fit(X_train, y_train)
y_pred = rfc_.predict(X_test)

# %%
cm_ = confusion_matrix(y_test, y_pred)
sns.heatmap(cm_, annot=True, fmt='d').set_title('Maternal risks confusion matrix (0 = No, 1 = Yes) for 900 trees with 8 levels')

print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       955
#            1       1.00      1.00      1.00       245
#
#     accuracy                           1.00      1200
#    macro avg       1.00      1.00      1.00      1200
# weighted avg       1.00      1.00      1.00      1200

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv("/content/BCG modified.csv")

# %%
dataset['Fault'] = dataset['Fault'].replace('No', 0).replace('Yes', 1)

# %%
y = dataset['Fault']
X = dataset.drop(['Fault'], axis=1)

# %%
from sklearn.model_selection import train_test_split

SEED = 42
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.2,
                                                    random_state=SEED)

# %%
from sklearn.ensemble import RandomForestRegressor

rfr = RandomForestRegressor(n_estimators=20,
                            max_depth=3,
                            random_state=SEED)

rfr.fit(X_train, y_train)
y_pred = rfr.predict(X_test)

# %%
from sklearn import tree

features = X.columns

first_tree = rfr.estimators_[0]

plt.figure(figsize=(15,6))
tree.plot_tree(first_tree,
               feature_names=features,
               fontsize=8,
               filled=True,
               rounded=True);

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

print('Mean Absolute Error:', mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 0.05125358975366741
# Mean Squared Error: 0.02971729603989755
# Root Mean Squared Error: 0.17238705299383
